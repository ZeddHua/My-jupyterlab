# %% [markdown]
# 勘察设计--正常数据

# %%
import pandas as pd
import os
count = 0
data = pd.read_excel (r"C:/Users/Zedd/Desktop/Summer intern/订单分析/待清洗/订单分析数据待清洗1-勘察设计.xlsx")
rows = data.shape [0]
department_list = []
classPath = r'C:/Users/Zedd/Desktop/Summer intern/订单分析/'
for i in range (rows):
    temp = data [r"主体院名称"] [i]
    if temp not in department_list:
        department_list.append (temp)  # 将部门的分类存在一个列表中
for department in department_list:
    new_df = pd.DataFrame ()
    for i in range (0, rows):
        if data["主体院名称"] [i] == department:
            new_df = pd.concat ([new_df, data.iloc [[i], :]], axis=0, ignore_index=True)
    if isinstance(department,str):
        # os.mkdir(classPath+department)
        new_df.to_excel(classPath+department+'/'+'.xlsx',encoding='utf_8_sig',index=False)
        print(department)
        count+=1
        print(count)
# Out:
# 上海市政交通设计研究院有限公司
# 1
# 水利水运设计研究院
# 2
# 城市建筑设计研究院
# 3
# 道路桥梁设计研究院
# 4
# 综合交通规划设计研究院
# 5
# 上海市政工程设计研究总院集团第六设计院有限公司
# 6
# 综合设计研究院
# 7
# 大桥设计研究院
# 8
# 上海市政工程设计研究总院集团第十市政设计院有限公司
# 9
# 第一设计研究院
# 10
# 上海斯美设计审图咨询有限公司
# 11
# 城市交通与地下空间设计研究院
# 12
# 第三设计研究院
# 13
# 第四设计研究院
# 14
# 景观规划设计研究院
# 15
# 第二设计研究院
# 16
# 研究院
# 17
# 第五设计研究院
# 18
# 城乡规划设计研究院
# 19
# 勘察设计院
# 20
# 工程造价咨询研究院
# 21
# 上海市政工程设计研究总院集团第七设计院有限公司
# 22
# 上海市政工程造价咨询有限公司
# 23
# 上海市政工程设计研究总院集团广东有限公司
# 24
# 研究院（土壤中心）
# 25
# 上海市政工程设计研究总院集团新疆有限公司
# 26
# 上海市政工程设计有限公司
# 27
# 数字工程设计院
# 28
# 上海城市空间建筑设计有限公司
# 29
# 上海水业设计工程有限公司
# 30
# 上海城市交通设计院有限公司
# 31
# 上海市政工程检测中心有限公司
# 32
# 上海市政工程设计科学研究所有限公司
# 33
# 上海市政建设工程有限公司
# 34
# 上海申环环境工程有限公司
# 35
# 城市轨道与铁路设计研究院
# 36

# %% [markdown]
# 勘察设计--xmsxppp错误值

# %%
import pandas as pd
import os
count = 0
data = pd.read_excel (r"C:/Users/Zedd/Desktop/Summer intern/订单分析/待清洗/订单分析数据待清洗3项目属性细分错误值-勘察设计.xlsx")
rows = data.shape [0]
department_list = []
classPath = r'C:/Users/Zedd/Desktop/Summer intern/订单分析/待清洗/勘察设计/'
for i in range (rows):
    temp = data [r"主体院名称"] [i]
    if temp not in department_list:
        department_list.append (temp)  # 将部门的分类存在一个列表中
for department in department_list:
    new_df = pd.DataFrame ()
    for i in range (0, rows):
        if data["主体院名称"] [i] == department:
            new_df = pd.concat ([new_df, data.iloc [[i], :]], axis=0, ignore_index=True)
    if isinstance(department,str):
        # os.mkdir(classPath+department)
        new_df.to_excel(classPath+department+'/'+department+'项目属性错误值'+'.xlsx',encoding='utf_8_sig',index=False)
        print(department)
        count+=1
        print(count)
# Out:
# 上海市政工程设计研究总院集团第十市政设计院有限公司
# 1
# 上海斯美设计审图咨询有限公司
# 2
# 景观规划设计研究院
# 3
# 第四设计研究院
# 4
# 综合设计研究院
# 5
# 道路桥梁设计研究院
# 6
# 第二设计研究院
# 7
# 综合交通规划设计研究院
# 8
# 城市建筑设计研究院
# 9
# 第一设计研究院
# 10
# 第五设计研究院
# 11
# 上海市政交通设计研究院有限公司
# 12
# 第三设计研究院
# 13
# 大桥设计研究院
# 14
# 水利水运设计研究院
# 15
# 城市交通与地下空间设计研究院
# 16
# 上海市政工程设计研究总院集团第六设计院有限公司
# 17
# 研究院
# 18
# 上海市政工程造价咨询有限公司
# 19
# 勘察设计院
# 20
# 上海市政工程设计研究总院集团广东有限公司
# 21
# 城乡规划设计研究院
# 22
# 研究院（土壤中心）
# 23
# 上海市政工程设计研究总院集团新疆有限公司
# 24
# 上海市政工程设计有限公司
# 25
# 上海水业设计工程有限公司
# 26
# 上海城市交通设计院有限公司
# 27
# 上海城市空间建筑设计有限公司
# 28
# 上海市政工程检测中心有限公司
# 29
# 工程造价咨询研究院
# 30
# 数字工程设计院
# 31
# 城市轨道与铁路设计研究院
# 32
# 上海申环环境工程有限公司
# 33

# %% [markdown]
# 总承包--正常数据

# %%
import pandas as pd
import os
count = 0
data = pd.read_excel (r"C:/Users/Zedd/Desktop/Summer intern/订单分析/待清洗/订单分析数据待清洗2-总承包.xlsx")
rows = data.shape [0]
department_list = []
classPath = r'C:/Users/Zedd/Desktop/Summer intern/订单分析/待清洗/总承包/'
for i in range (rows):
    temp = data [r"主体院名称"] [i]
    if temp not in department_list:
        department_list.append (temp)  # 将部门的分类存在一个列表中
for department in department_list:
    new_df = pd.DataFrame ()
    for i in range (0, rows):
        if data["主体院名称"] [i] == department:
            new_df = pd.concat ([new_df, data.iloc [[i], :]], axis=0, ignore_index=True)
    if isinstance(department,str):
        os.mkdir(classPath+department)
        new_df.to_excel(classPath+department+'/'+department+'.xlsx',encoding='utf_8_sig',index=False)
        
        print(department)
        count+=1
        print(count)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-20-b295e9e1b8ce> in <module>
#      16             new_df = pd.concat ([new_df, data.iloc [[i], :]], axis=0, ignore_index=True)
#      17     if isinstance(department,str):
# ---> 18         os.mkdir(classPath+department)
#      19         new_df.to_excel(classPath+department+'/'+department+'.xlsx',encoding='utf_8_sig',index=False)
#      20         print(department)
#
# FileExistsError: [WinError 183] 当文件已存在时，无法创建该文件。: 'C:/Users/Zedd/Desktop/Summer intern/订单分析/待清洗/总承包/第一设计研究院'

# %% [markdown]
# 总承包--xmsxppp错误值

# %%
import pandas as pd
import os
count = 0
data = pd.read_excel (r"C:/Users/Zedd/Desktop/Summer intern/订单分析/待清洗/订单分析数据待清洗3项目属性细分错误值-总承包.xlsx")
rows = data.shape [0]
department_list = []
classPath = r'C:/Users/Zedd/Desktop/Summer intern/订单分析/待清洗/总承包/'
for i in range (rows):
    temp = data [r"主体院名称"] [i]
    if temp not in department_list:
        department_list.append (temp)  # 将部门的分类存在一个列表中
for department in department_list:
    new_df = pd.DataFrame ()
    for i in range (0, rows):
        if data["主体院名称"] [i] == department:
            new_df = pd.concat ([new_df, data.iloc [[i], :]], axis=0, ignore_index=True)
    if isinstance(department,str):
        # os.mkdir(classPath+department)
        #if data["主体院名称"] [i] != '研究院（土壤中心）':
        new_df.to_excel(classPath+department+'/'+department+'项目属性错误值'+'.xlsx',encoding='utf_8_sig',index=False)
        print(department)
        count+=1
        print(count)
# Out:
# 第三设计研究院
# 1
# 城市建筑设计研究院
# 2
# 大桥设计研究院
# 3
# 城市交通与地下空间设计研究院
# 4
# 第一设计研究院
# 5
# 上海水业设计工程有限公司
# 6
# 综合设计研究院
# 7
# 研究院
# 8
# 上海市政工程设计科学研究所有限公司
# 9
# 第二设计研究院
# 10
# 上海市政交通设计研究院有限公司
# 11
# 综合交通规划设计研究院
# 12
# 道路桥梁设计研究院
# 13
# 景观规划设计研究院
# 14
# 第五设计研究院
# 15
# 第四设计研究院
# 16
# 水利水运设计研究院
# 17
# 研究院（土壤中心）
# 18

# %% [markdown]
# DATA_VALIDATION 数据验证 lov

# %%
from openpyxl  import Workbook

from openpyxl  import load_workbook

from openpyxl.worksheet.datavalidation import DataValidation

# %% [markdown]
# prototype

# %%
    # Create the workbook and worksheet we'll be working with

    wb = load_workbook(r'C:\Users\Zedd\Desktop\test1.xlsx')

    print(wb.sheetnames)  

    ws = wb.active

    print('打开文件')

    # Create a data-validation object with list validation

    dv = DataValidation(type="list", formula1='"Dog,Cat,Bat"', allow_blank=True)

 

    # Optionally set a custom error message

    dv.error ='Your entry is not in the list'

    dv.errorTitle = 'Invalid Entry'

 

    # Optionally set a custom prompt message

    dv.prompt = 'Please select from the list'

    dv.promptTitle = 'List Selection'

    print('设置数据有效性')

    #设置验证的单元格范围

    #c1=ws['A5']

    dv.add('A1:A5')

    # Add the data-validation object to the worksheet

    ws.add_data_validation(dv)

    wb.save(r'C:\Users\Zedd\Desktop\test1.xlsx')

    print('设置成功')
# Out:
# ['Sheet1', 'Sheet2']
# 打开文件
# 设置数据有效性
# 设置成功

# %% [markdown]
# application

# %%
    # Create the workbook and worksheet we'll be working with
    wb = load_workbook(r'C:\Users\Zedd\Desktop\test1.xlsx')
    ws = wb.active

    # Create a data-validation object with list validation
    dv1 = DataValidation(type="list", formula1='"合同,接话单,委托单,中标书"', allow_blank=True)
    dv2 = DataValidation(type="list", formula1='"前期跟踪,公开招标,业主邀请,其他"', allow_blank=True)
    dv3 = DataValidation(type="list", formula1='"是,否"', allow_blank=True)
    dv4 = DataValidation(type="list", formula1='"勘察设计(工程勘察),勘察设计(工程设计),勘察设计(勘察设计一体化),勘察设计(PPP),勘察设计(EPC牵头),勘察设计(EPC成员),咨询服务(前期咨询),咨询服务(规划),咨询服务(BIM),咨询服务(技术服务),咨询服务(EPC牵头技术服务),咨询服务(EPC牵头BIM),咨询服务(勘察设计审查),咨询服务(全过程工程咨询)"', allow_blank=True)
 
    #设置验证的单元格范围
    dv1.add('N2:N1048576')
    dv2.add('O2:O1048576')
    dv3.add('L2:L1048576')
    dv4.add('S2:S1048576')

    # Add the data-validation object to the worksheet
    ws.add_data_validation(dv1)
    ws.add_data_validation(dv2)
    ws.add_data_validation(dv3)
    ws.add_data_validation(dv4)

    wb.save(r'C:\Users\Zedd\Desktop\test1.xlsx')

    print('设置成功')
# Out:
#   File "<ipython-input-31-a0b0b36a6a57>", line 3
#     wb = load_workbook(r'C:\Users\Zedd\Desktop\test1.xlsx')
#     ^
# IndentationError: unexpected indent

# %%
import pandas as pd
import os
count = 0
data = pd.read_excel (r"C:/Users/Zedd/Desktop/Summer intern/订单分析/待清洗/订单分析数据待清洗3项目属性细分错误值-勘察设计.xlsx")
rows = data.shape [0]
department_list = []
classPath = r'C:/Users/Zedd/Desktop/Summer intern/订单分析/待清洗/勘察设计/'
for i in range (rows):
    temp = data [r"主体院名称"] [i]
    if temp not in department_list:
        department_list.append (temp)  # 将部门的分类存在一个列表中
for department in department_list:
    new_df = pd.DataFrame ()
    for i in range (0, rows):
        if data["主体院名称"] [i] == department:
            new_df = pd.concat ([new_df, data.iloc [[i], :]], axis=0, ignore_index=True)
    if isinstance(department,str):
        # os.mkdir(classPath+department)
        new_df.to_excel(classPath+department+'/'+department+'项目属性错误值'+'.xlsx',encoding='utf_8_sig',index=False)
        #数据验证
        # Create the workbook and worksheet we'll be working with
        wb = load_workbook(classPath+department+'/'+department+'项目属性错误值'+'.xlsx')
        ws = wb.active

        # Create a data-validation object with list validation
        dv1 = DataValidation(type="list", formula1='"合同,接话单,委托单,中标书"', allow_blank=True)
        dv2 = DataValidation(type="list", formula1='"前期跟踪,公开招标,业主邀请,其他"', allow_blank=True)
        dv3 = DataValidation(type="list", formula1='"是,否"', allow_blank=True)
        dv4 = DataValidation(type="list", formula1='"勘察设计(工程勘察),勘察设计(工程设计),勘察设计(勘察设计一体化),勘察设计(PPP),勘察设计(EPC牵头),勘察设计(EPC成员),咨询服务(前期咨询),咨询服务(规划),咨询服务(BIM),咨询服务(技术服务),咨询服务(EPC牵头技术服务),咨询服务(EPC牵头BIM),咨询服务(勘察设计审查),咨询服务(全过程工程咨询)"', allow_blank=True)
 
        #设置验证的单元格范围
        dv1.add('N2:N1048576')
        dv2.add('O2:O1048576')
        dv3.add('L2:L1048576')
        dv4.add('S2:S1048576')

        # Add the data-validation object to the worksheet
        ws.add_data_validation(dv1)
        ws.add_data_validation(dv2)
        ws.add_data_validation(dv3)
        ws.add_data_validation(dv4)

        wb.save(classPath+department+'/'+department+'项目属性错误值'+'.xlsx')

        print('设置成功')
        #数据验证
        print(department)
        count+=1
        print(count)
# Out:
# 设置成功
# 上海市政工程设计研究总院集团第十市政设计院有限公司
# 1
# 设置成功
# 上海斯美设计审图咨询有限公司
# 2
# 设置成功
# 景观规划设计研究院
# 3
# 设置成功
# 第四设计研究院
# 4
# 设置成功
# 综合设计研究院
# 5
# 设置成功
# 道路桥梁设计研究院
# 6
# 设置成功
# 第二设计研究院
# 7
# 设置成功
# 综合交通规划设计研究院
# 8
# 设置成功
# 城市建筑设计研究院
# 9
# 设置成功
# 第一设计研究院
# 10
# 设置成功
# 第五设计研究院
# 11
# 设置成功
# 上海市政交通设计研究院有限公司
# 12
# 设置成功
# 第三设计研究院
# 13
# 设置成功
# 大桥设计研究院
# 14
# 设置成功
# 水利水运设计研究院
# 15
# 设置成功
# 城市交通与地下空间设计研究院
# 16
# 设置成功
# 上海市政工程设计研究总院集团第六设计院有限公司
# 17
# 设置成功
# 研究院
# 18
# 设置成功
# 上海市政工程造价咨询有限公司
# 19
# 设置成功
# 勘察设计院
# 20
# 设置成功
# 上海市政工程设计研究总院集团广东有限公司
# 21
# 设置成功
# 城乡规划设计研究院
# 22
# 设置成功
# 研究院（土壤中心）
# 23
# 设置成功
# 上海市政工程设计研究总院集团新疆有限公司
# 24
# 设置成功
# 上海市政工程设计有限公司
# 25
# 设置成功
# 上海水业设计工程有限公司
# 26
# 设置成功
# 上海城市交通设计院有限公司
# 27
# 设置成功
# 上海城市空间建筑设计有限公司
# 28
# 设置成功
# 上海市政工程检测中心有限公司
# 29
# 设置成功
# 工程造价咨询研究院
# 30
# 设置成功
# 数字工程设计院
# 31
# 设置成功
# 城市轨道与铁路设计研究院
# 32
# 设置成功
# 上海申环环境工程有限公司
# 33

# %%
import pandas as pd
import os
count = 0
data = pd.read_excel (r"C:/Users/Zedd/Desktop/Summer intern/订单分析/待清洗/订单分析数据待清洗3项目属性细分错误值-总承包.xlsx")
rows = data.shape [0]
department_list = []
classPath = r'C:/Users/Zedd/Desktop/Summer intern/订单分析/待清洗/总承包/'
for i in range (rows):
    temp = data [r"主体院名称"] [i]
    if temp not in department_list:
        department_list.append (temp)  # 将部门的分类存在一个列表中
for department in department_list:
    new_df = pd.DataFrame ()
    for i in range (0, rows):
        if data["主体院名称"] [i] == department:
            new_df = pd.concat ([new_df, data.iloc [[i], :]], axis=0, ignore_index=True)
    if isinstance(department,str):
        # os.mkdir(classPath+department)
        #if data["主体院名称"] [i] != '研究院（土壤中心）':
        new_df.to_excel(classPath+department+'/'+department+'项目属性错误值'+'.xlsx',encoding='utf_8_sig',index=False)
            # Create the workbook and worksheet we'll be working with
        wb = load_workbook(classPath+department+'/'+department+'项目属性错误值'+'.xlsx')
        ws = wb.active

        # Create a data-validation object with list validation
        dv1 = DataValidation(type="list", formula1='"合同,接话单,委托单,中标书"', allow_blank=True)
        dv2 = DataValidation(type="list", formula1='"前期跟踪,公开招标,业主邀请,其他"', allow_blank=True)
        dv3 = DataValidation(type="list", formula1='"是,否"', allow_blank=True)
        dv4 = DataValidation(type="list", formula1='"EPC(设计采购施工),EPC(施工总承包),EPC(项目管理)"', allow_blank=True)
        dv5 = DataValidation(type="list", formula1='"自营（全部自营）,自营（项目管理）,自营（设备采购）,联合（纯联合体）,联合（部分自营）"', allow_blank=True)
        dv6 = DataValidation(type="list", formula1='"联合体,设备采购,项目管理（代建）,自营,自营+联合体"', allow_blank=True)
        #dv7 = DataValidation(type="list", formula1='"第四设计研究院,第五设计研究院,道路桥梁设计研究院,综合交通规划设计研究院,第一设计研究院,景观规划设计研究院,上海市政交通设计研究院有限公司,城市建筑设计研究院,上海市政工程设计研究总院集团第十市政设计院有限公司,大桥设计研究院,上海市政工程设计研究总院集团第六设计院有限公司,上海城市交通设计院有限公司,水利水运设计研究院,工程造价咨询研究院,综合设计研究院,城市交通与地下空间设计研究院,城乡规划设计研究院,勘察设计院,上海市政工程检测中心有限公司,上海市政工程设计科学研究所有限公司,上海市政建设工程有限公司,上海市政工程造价咨询有限公司,上海水业设计工程有限公司,上海斯美设计审图咨询有限公司,上海市政工程设计有限公司,研究院,第二设计研究院,第三设计研究院,上海城市空间建筑设计有限公司,上海申环环境工程有限公司,城市轨道与铁路设计研究院,研究院（土壤中心）,上海市政工程设计研究总院集团广东有限公司,上海市政工程设计研究总院集团新疆有限公司,数字工程设计院"', allow_blank=True)

        #设置验证的单元格范围
        dv1.add('N2:N1048576')
        dv2.add('O2:O1048576')
        dv3.add('L2:L1048576')
        dv4.add('U2:U1048576')
        dv5.add('Q2:Q1048576')
        dv6.add('P2:P1048576')
        #dv7.add('J2:J1048576')

        # Add the data-validation object to the worksheet
        ws.add_data_validation(dv1)
        ws.add_data_validation(dv2)
        ws.add_data_validation(dv3)
        ws.add_data_validation(dv4)
        ws.add_data_validation(dv5)
        ws.add_data_validation(dv6)
        #ws.add_data_validation(dv7)

        wb.save(classPath+department+'/'+department+'项目属性错误值'+'.xlsx')

        print('设置成功')
        print(department)
        count+=1
        print(count)
# Out:
# 设置成功
# 第三设计研究院
# 1
# 设置成功
# 城市建筑设计研究院
# 2
# 设置成功
# 大桥设计研究院
# 3
# 设置成功
# 城市交通与地下空间设计研究院
# 4
# 设置成功
# 第一设计研究院
# 5
# 设置成功
# 上海水业设计工程有限公司
# 6
# 设置成功
# 综合设计研究院
# 7
# 设置成功
# 研究院
# 8
# 设置成功
# 上海市政工程设计科学研究所有限公司
# 9
# 设置成功
# 第二设计研究院
# 10
# 设置成功
# 上海市政交通设计研究院有限公司
# 11
# 设置成功
# 综合交通规划设计研究院
# 12
# 设置成功
# 道路桥梁设计研究院
# 13
# 设置成功
# 景观规划设计研究院
# 14
# 设置成功
# 第五设计研究院
# 15
# 设置成功
# 第四设计研究院
# 16
# 设置成功
# 水利水运设计研究院
# 17
# 设置成功
# 研究院（土壤中心）
# 18

# %%
import pandas as pd
import os
count = 0
data = pd.read_excel (r"C:/Users/Zedd/Desktop/Summer intern/订单分析/待清洗/订单分析数据待清洗2-总承包.xlsx")
rows = data.shape [0]
department_list = []
classPath = r'C:/Users/Zedd/Desktop/Summer intern/订单分析/待清洗/总承包/'
for i in range (rows):
    temp = data [r"主体院名称"] [i]
    if temp not in department_list:
        department_list.append (temp)  # 将部门的分类存在一个列表中
for department in department_list:
    new_df = pd.DataFrame ()
    for i in range (0, rows):
        if data["主体院名称"] [i] == department:
            new_df = pd.concat ([new_df, data.iloc [[i], :]], axis=0, ignore_index=True)
    if isinstance(department,str):
        # os.mkdir(classPath+department)
        new_df.to_excel(classPath+department+'/'+department+'.xlsx',encoding='utf_8_sig',index=False)
        
        wb = load_workbook(classPath+department+'/'+department+'.xlsx')
        ws = wb.active

        # Create a data-validation object with list validation
        dv1 = DataValidation(type="list", formula1='"合同,接话单,委托单,中标书"', allow_blank=True)
        dv2 = DataValidation(type="list", formula1='"前期跟踪,公开招标,业主邀请,其他"', allow_blank=True)
        dv3 = DataValidation(type="list", formula1='"是,否"', allow_blank=True)
        dv4 = DataValidation(type="list", formula1='"EPC(设计采购施工),EPC(施工总承包),EPC(项目管理)"', allow_blank=True)
        dv5 = DataValidation(type="list", formula1='"自营（全部自营）,自营（项目管理）,自营（设备采购）,联合（纯联合体）,联合（部分自营）"', allow_blank=True)
        dv6 = DataValidation(type="list", formula1='"联合体,设备采购,项目管理（代建）,自营,自营+联合体"', allow_blank=True)

        #设置验证的单元格范围
        dv1.add('N2:N1048576')
        dv2.add('O2:O1048576')
        dv3.add('L2:L1048576')
        dv4.add('S2:S1048576')
        dv5.add('Q2:Q1048576')
        dv6.add('P2:P1048576')

        # Add the data-validation object to the worksheet
        ws.add_data_validation(dv1)
        ws.add_data_validation(dv2)
        ws.add_data_validation(dv3)
        ws.add_data_validation(dv4)
        ws.add_data_validation(dv5)
        ws.add_data_validation(dv6)

        wb.save(classPath+department+'/'+department+'.xlsx')

        print('设置成功')
        print(department)
        count+=1
        print(count)
# Out:
# 设置成功
# 第一设计研究院
# 1
# 设置成功
# 第二设计研究院
# 2
# 设置成功
# 第三设计研究院
# 3
# 设置成功
# 景观规划设计研究院
# 4
# 设置成功
# 研究院
# 5
# 设置成功
# 道路桥梁设计研究院
# 6
# 设置成功
# 大桥设计研究院
# 7
# 设置成功
# 上海市政建设工程有限公司
# 8
# 设置成功
# 第四设计研究院
# 9
# 设置成功
# 综合交通规划设计研究院
# 10
# 设置成功
# 城市交通与地下空间设计研究院
# 11
# 设置成功
# 第五设计研究院
# 12
# 设置成功
# 水利水运设计研究院
# 13
# 设置成功
# 综合设计研究院
# 14
# 设置成功
# 上海市政工程设计研究总院集团第十市政设计院有限公司
# 15
# 设置成功
# 上海市政交通设计研究院有限公司
# 16
# 设置成功
# 上海市政工程设计研究总院集团广东有限公司
# 17
# 设置成功
# 城市建筑设计研究院
# 18
# 设置成功
# 上海水业设计工程有限公司
# 19
# 设置成功
# 上海市政工程设计科学研究所有限公司
# 20
# 设置成功
# 上海申环环境工程有限公司
# 21

# %%
from openpyxl  import Workbook
from openpyxl  import load_workbook
# from openpyxl.worksheet.datavalidation import DataValidation
from openpyxl.styles import fills,Font,PatternFill,Alignment
wb = load_workbook(r'C:\Users\Zedd\Desktop\test1.xlsx')
print(wb.sheetnames)  
ws = wb.active
alignment=Alignment(horizontal='center',#水平'center', 'centerContinuous', 'justify', 'fill', 'general', 'distributed', 'left', 'right'
            vertical='top',#垂直'distributed', 'bottom', 'top', 'center', 'justify'
            text_rotation=0,#旋转角度0~180
            wrap_text=False,#文字换行
            shrink_to_fit=True,#自适应宽度，改变文字大小,上一项false
            indent=0)
fill = PatternFill(fill_type="solid",start_color='FFD9D919')
ws['A1'].alignment = alignment
ws["A1"].fill = fill

wb.save(r'C:\Users\Zedd\Desktop\test1.xlsx')
# Out:
# ['Sheet1']

# %%
import pandas as pd
data1 = pd.read_excel (r"C:/Users/Zedd/Desktop/Summer intern/订单分析/待清洗/订单分析数据待清洗2-总承包.xlsx")

# %%
data1.shape
# Out:
# (562, 20)

# %%
data1.shape[0]
# Out:
# 562

# %%
data1.head()
# Out:
#   项目类型  组织名称        项目编号                          项目全称   省份   城市     项目批准日期  \
# 0  总承包  市政总院  2009-ZQ-03               都江堰西区自来水厂清水管网工程  四川省  成都市 2009-10-01
# 1  总承包  市政总院  2011-SQ-01  常熟市滨江水厂扩建工程（净水厂）设备采购及安装总承包项目  江苏省  苏州市 2011-09-10
# 2  总承包  市政总院  2010-SQ-01        淄博市城乡同源同网饮水安全供水工程净水厂工程  山东省  淄博市 2010-04-25
# 3  总承包  市政总院  2008-ZS-02                    金海水厂（一期）工程  上海市  上海市 2008-11-01
# 4  总承包  市政总院  2011-ZS-01              老港综合填埋场垃圾渗沥液处理工程  上海市  上海市 2011-06-01
#
#      项目阶段                   客户名称    主体院名称 项目特征分类 是否中标 中标金额 项目信息来源 投标信息来源  \
# 0  EPC总承包  上海对口支援灾后重建都江堰项目管理有限公司  第一设计研究院   给水工程  NaN  NaN    NaN    NaN
# 1   施工总承包           江苏中法水务股份有限公司  第二设计研究院   给水工程  NaN  NaN    NaN    NaN
# 2   施工总承包               淄博市自来水公司  第二设计研究院   给水工程  NaN  NaN    NaN    NaN
# 3   施工总承包         上海浦东威立雅自来水有限公司  第二设计研究院   给水工程  NaN  NaN    NaN    NaN
# 4  EPC总承包         上海老港固废综合开发有限公司  第三设计研究院   排水工程  NaN  NaN    NaN    NaN
#
#   项目管理模式细分    项目管理模式  预估阶段金额 项目属性细分  预估报价金额
# ...

# %%
data1["主体院名称"][1]
# Out:
# '第二设计研究院'

# %%
data1["主体院名称"].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 557    False
# 558    False
# 559    False
# 560    False
# 561    False
# Name: 主体院名称, Length: 562, dtype: bool

# %%
from openpyxl  import Workbook
from openpyxl  import load_workbook
from openpyxl.styles import fills,Font,PatternFill,Alignment
from openpyxl.worksheet.datavalidation import DataValidation
import pandas as pd
import os
count = 0
data = pd.read_excel (r"C:/Users/Zedd/Desktop/Summer intern/订单分析/待清洗/订单分析数据待清洗2-总承包.xlsx")
rows = data.shape [0]
department_list = []
classPath = r'C:/Users/Zedd/Desktop/Summer intern/订单分析/待清洗/总承包/'
for i in range (rows):
    temp = data [r"主体院名称"] [i]
    if temp not in department_list:
        department_list.append (temp)  # 将部门的分类存在一个列表中
for department in department_list:
    new_df = pd.DataFrame ()
    for i in range (0, rows):
        if data["主体院名称"] [i] == department:
            new_df = pd.concat ([new_df, data.iloc [[i], :]], axis=0, ignore_index=True)
    if isinstance(department,str):
        # os.mkdir(classPath+department)
        new_df.to_excel(classPath+department+'/'+department+'.xlsx',encoding='utf_8_sig',index=False)
        
        wb = load_workbook(classPath+department+'/'+department+'.xlsx')
        ws = wb.active

        # Create a data-validation object with list validation
        dv1 = DataValidation(type="list", formula1='"合同,接话单,委托单,中标书"', allow_blank=True)
        dv2 = DataValidation(type="list", formula1='"前期跟踪,公开招标,业主邀请,其他"', allow_blank=True)
        dv3 = DataValidation(type="list", formula1='"是,否"', allow_blank=True)
        dv4 = DataValidation(type="list", formula1='"EPC(设计采购施工),EPC(施工总承包),EPC(项目管理)"', allow_blank=True)
        dv5 = DataValidation(type="list", formula1='"自营（全部自营）,自营（项目管理）,自营（设备采购）,联合（纯联合体）,联合（部分自营）"', allow_blank=True)
        dv6 = DataValidation(type="list", formula1='"联合体,设备采购,项目管理（代建）,自营,自营+联合体"', allow_blank=True)

        #设置验证的单元格范围
        dv1.add('N2:N1048576')
        dv2.add('O2:O1048576')
        dv3.add('L2:L1048576')
        dv4.add('S2:S1048576')
        dv5.add('Q2:Q1048576')
        dv6.add('P2:P1048576')

        # Add the data-validation object to the worksheet
        ws.add_data_validation(dv1)
        ws.add_data_validation(dv2)
        ws.add_data_validation(dv3)
        ws.add_data_validation(dv4)
        ws.add_data_validation(dv5)
        ws.add_data_validation(dv6)
        
        fill = PatternFill(fill_type="solid",start_color='FFD9D919')
        
        for i in range(rows):
            if type(data["项目管理模式细分"][i])== 'float':
                data["项目管理模式细分"][i].fill=fill
        
        wb.save(classPath+department+'/'+department+'.xlsx')

        print('设置成功')
        print(department)
        count+=1
        print(count)
# Out:
# 设置成功
# 第一设计研究院
# 1
# 设置成功
# 第二设计研究院
# 2
# 设置成功
# 第三设计研究院
# 3
# 设置成功
# 景观规划设计研究院
# 4
# 设置成功
# 研究院
# 5
# 设置成功
# 道路桥梁设计研究院
# 6
# 设置成功
# 大桥设计研究院
# 7
# 设置成功
# 上海市政建设工程有限公司
# 8
# 设置成功
# 第四设计研究院
# 9
# 设置成功
# 综合交通规划设计研究院
# 10
# 设置成功
# 城市交通与地下空间设计研究院
# 11
# 设置成功
# 第五设计研究院
# 12
# 设置成功
# 水利水运设计研究院
# 13
# 设置成功
# 综合设计研究院
# 14
# 设置成功
# 上海市政工程设计研究总院集团第十市政设计院有限公司
# 15
# 设置成功
# 上海市政交通设计研究院有限公司
# 16
# 设置成功
# 上海市政工程设计研究总院集团广东有限公司
# 17
# 设置成功
# 城市建筑设计研究院
# 18
# 设置成功
# 上海水业设计工程有限公司
# 19
# 设置成功
# 上海市政工程设计科学研究所有限公司
# 20
# 设置成功
# 上海申环环境工程有限公司
# 21
