# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
data=pd.read_excel(r'C:\Users\Zedd\Desktop\us.xlsx')
data
# Out:
#           date    cases  deaths
# 0   2020-01-19        0       0
# 1   2020-01-20        0       0
# 2   2020-01-21        1       0
# 3   2020-01-22        1       0
# 4   2020-01-23        1       0
# ..         ...      ...     ...
# 263 2020-10-08  7639252  212678
# 264 2020-10-09  7698203  213593
# 265 2020-10-10  7749789  214185
# 266 2020-10-11  7794555  214604
# 267 2020-10-12  7840482  214955
#
# [268 rows x 3 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268 entries, 0 to 267
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    268 non-null    datetime64[ns]
#  1   cases   268 non-null    int64
#  2   deaths  268 non-null    int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 6.4 KB

# %%
sns.lineplot(x='date',y='cases',data=data)
# Out:
# <AxesSubplot:xlabel='date', ylabel='cases'>
