# %% [markdown]
# **<font color=red>-----勘察设计-下达项目-----</font>**

# %%
import os
import pandas as pd

t=0
new_list=[]
zty_list=['上海市政交通设计研究院有限公司','研究院','综合设计研究院','第五设计研究院','水利水运设计研究院','上海市政工程设计研究总院集团第十市政设计院有限公司','研究院（土壤中心）','景观规划设计研究院','城市建筑设计研究院','第二设计研究院','工程造价咨询研究院','第四设计研究院','上海市政工程设计研究总院集团新疆有限公司','上海水业设计工程有限公司','上海斯美设计审图咨询有限公司','数字工程设计院','勘察设计院','第三设计研究院','上海市政工程设计研究总院集团第六设计院有限公司','城乡规划设计研究院','城市轨道与铁路设计研究院','道路桥梁设计研究院','综合交通规划设计研究院','大桥设计研究院','上海城市交通设计院有限公司','城市交通与地下空间设计研究院','上海市政工程设计研究总院集团广东有限公司']
file_list=['市政交通院','研究院','综合院','五院','水利水运院','十院','申环公司，没表2','景观院','建筑院','二院','造价公司','四院','新疆公司','水业公司','审图公司','数字院，仅表3','勘察公司','三院','六院','规划院','轨道铁路院，无表1','道桥院','交规院','大桥院','城市交通院','城郊地下院','广东公司']
list1=['申环公司，没表2','数字院，仅表3']
for i in file_list:
    if  i not in list1:
        path="C:\\Users\\Zedd\\Desktop\\Summer intern\\订单分析\\待清洗\\回复22-勘察设计\\" +i
        df=pd.read_excel(path+'\订单分析待清洗-勘察设计-下达项目.xlsx')
        #df=df.drop(df[df['主体院名称\n（值列表点选勿手输）']!=zty_list[t]])
        df1=df[df['主体院名称\n（值列表点选勿手输）']==zty_list[t]]
        new_list.append(df1)
        print(zty_list[t])
        t+=1
    else:
        print('jump over'+zty_list[t])
        t+=1
        continue
df2=pd.concat(new_list)
df2.to_excel(r'C:\Users\Zedd\Desktop\test.xlsx',index=False)

# %% [markdown]
# **<font color=red>-----勘察设计-投标-----</font>**

# %%
import os
import pandas as pd

t=0
new_list=[]
zty_list=['上海市政交通设计研究院有限公司','研究院','综合设计研究院','第五设计研究院','水利水运设计研究院','上海市政工程设计研究总院集团第十市政设计院有限公司','研究院（土壤中心）','景观规划设计研究院','城市建筑设计研究院','第二设计研究院','工程造价咨询研究院','第四设计研究院','上海市政工程设计研究总院集团新疆有限公司','上海水业设计工程有限公司','上海斯美设计审图咨询有限公司','数字工程设计院','勘察设计院','第三设计研究院','上海市政工程设计研究总院集团第六设计院有限公司','城乡规划设计研究院','城市轨道与铁路设计研究院','道路桥梁设计研究院','综合交通规划设计研究院','大桥设计研究院','上海城市交通设计院有限公司','城市交通与地下空间设计研究院','上海市政工程设计研究总院集团广东有限公司']
file_list=['市政交通院','研究院','综合院','五院','水利水运院','十院','申环公司，没表2','景观院','建筑院','二院','造价公司','四院','新疆公司','水业公司','审图公司','数字院，仅表3','勘察公司','三院','六院','规划院','轨道铁路院，无表1','道桥院','交规院','大桥院','城市交通院','城郊地下院','广东公司']
list1=['申环公司，没表2','数字院，仅表3']
list2=['轨道铁路院，无表1','数字院，仅表3']
list3=[]
list4=['数字院，仅表3']
for i in file_list:
    if  i not in list2:
        path="C:\\Users\\Zedd\\Desktop\\Summer intern\\订单分析\\待清洗\\回复22-勘察设计\\" +i
        df=pd.read_excel(path+'\订单分析数据待清洗-勘察设计-投标.xlsx')
        df1=df[df['主体院名称\n（值列表点选勿手输）']==zty_list[t]]
        new_list.append(df1)
        print(zty_list[t])
        t+=1
    else:
        print('jump over'+zty_list[t])
        t+=1
        continue
df2=pd.concat(new_list)
df2.to_excel(r'C:\Users\Zedd\Desktop\投标.xlsx',index=False)

# %% [markdown]
# **<font color=red>-----错误值-投标-----</font>**

# %%
import os
import pandas as pd

t=0
new_list=[]
zty_list=['上海市政交通设计研究院有限公司','研究院','综合设计研究院','第五设计研究院','水利水运设计研究院','上海市政工程设计研究总院集团第十市政设计院有限公司','研究院（土壤中心）','景观规划设计研究院','城市建筑设计研究院','第二设计研究院','工程造价咨询研究院','第四设计研究院','上海市政工程设计研究总院集团新疆有限公司','上海水业设计工程有限公司','上海斯美设计审图咨询有限公司','数字工程设计院','勘察设计院','第三设计研究院','上海市政工程设计研究总院集团第六设计院有限公司','城乡规划设计研究院','城市轨道与铁路设计研究院','道路桥梁设计研究院','综合交通规划设计研究院','大桥设计研究院','上海城市交通设计院有限公司','城市交通与地下空间设计研究院','上海市政工程设计研究总院集团广东有限公司']
file_list=['市政交通院','研究院','综合院','五院','水利水运院','十院','申环公司，没表2','景观院','建筑院','二院','造价公司','四院','新疆公司','水业公司','审图公司','数字院，仅表3','勘察公司','三院','六院','规划院','轨道铁路院，无表1','道桥院','交规院','大桥院','城市交通院','城郊地下院','广东公司']
list1=['申环公司，没表2','数字院，仅表3']
list2=['轨道铁路院，无表1','数字院，仅表3']
list3=[]
list4=['数字院，仅表3']
for i in file_list:
    if  i not in list3:
        path="C:\\Users\\Zedd\\Desktop\\Summer intern\\订单分析\\待清洗\\回复22-勘察设计\\" +i
        df=pd.read_excel(path+'\订单分析数据待清洗-项目属性细分错误值-勘察设计-投标.xlsx')
        df1=df[df['主体院名称']==zty_list[t]]
        new_list.append(df1)
        print(zty_list[t])
        t+=1
    else:
        print('jump over'+zty_list[t])
        t+=1
        continue
df2=pd.concat(new_list)
df2.to_excel(r'C:\Users\Zedd\Desktop\错误值-投标.xlsx',index=False)
# Out:
# 上海市政交通设计研究院有限公司
# 研究院
# 综合设计研究院
# 第五设计研究院
# 水利水运设计研究院
# 上海市政工程设计研究总院集团第十市政设计院有限公司
# 研究院（土壤中心）
# 景观规划设计研究院
# 城市建筑设计研究院
# 第二设计研究院
# 工程造价咨询研究院
# 第四设计研究院
# 上海市政工程设计研究总院集团新疆有限公司
# 上海水业设计工程有限公司
# 上海斯美设计审图咨询有限公司
# 数字工程设计院
# 勘察设计院
# 第三设计研究院
# 上海市政工程设计研究总院集团第六设计院有限公司
# 城乡规划设计研究院
# 城市轨道与铁路设计研究院
# 道路桥梁设计研究院
# 综合交通规划设计研究院
# 大桥设计研究院
# 上海城市交通设计院有限公司
# 城市交通与地下空间设计研究院
# 上海市政工程设计研究总院集团广东有限公司
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-59fc39deb7df> in <module>
#      22         t+=1
#      23         continue
# ---> 24 df2=pd.concat(new_list,ignore_index=False,keys=new_list,join='inner')
#      25 df2
#      26 #df2.to_excel(r'C:\Users\Zedd\Desktop\错误值-投标.xlsx',index=False)
#
# D:\Softwares Installed\Anaconda\anaconda\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
# ...

# %% [markdown]
# **<font color=red>-----错误值-下达项目-----</font>**

# %%
import os
import pandas as pd

t=0
new_list=[]
zty_list=['上海市政交通设计研究院有限公司','研究院','综合设计研究院','第五设计研究院','水利水运设计研究院','上海市政工程设计研究总院集团第十市政设计院有限公司','研究院（土壤中心）','景观规划设计研究院','城市建筑设计研究院','第二设计研究院','工程造价咨询研究院','第四设计研究院','上海市政工程设计研究总院集团新疆有限公司','上海水业设计工程有限公司','上海斯美设计审图咨询有限公司','数字工程设计院','勘察设计院','第三设计研究院','上海市政工程设计研究总院集团第六设计院有限公司','城乡规划设计研究院','城市轨道与铁路设计研究院','道路桥梁设计研究院','综合交通规划设计研究院','大桥设计研究院','上海城市交通设计院有限公司','城市交通与地下空间设计研究院','上海市政工程设计研究总院集团广东有限公司']
file_list=['市政交通院','研究院','综合院','五院','水利水运院','十院','申环公司，没表2','景观院','建筑院','二院','造价公司','四院','新疆公司','水业公司','审图公司','数字院，仅表3','勘察公司','三院','六院','规划院','轨道铁路院，无表1','道桥院','交规院','大桥院','城市交通院','城郊地下院','广东公司']
list1=['申环公司，没表2','数字院，仅表3']
list2=['轨道铁路院，无表1','数字院，仅表3']
list3=[]
list4=['数字院，仅表3']
for i in file_list:
    if  i not in list4:
        path="C:\\Users\\Zedd\\Desktop\\Summer intern\\订单分析\\待清洗\\回复22-勘察设计\\" +i
        df=pd.read_excel(path+'\订单分析数据待清洗-项目属性细分错误值-勘察设计-下达项目.xlsx')
        df1=df[df['主体院名称']==zty_list[t]]
        new_list.append(df1)
        print(zty_list[t])
        t+=1
    else:
        print('jump over'+zty_list[t])
        t+=1
        continue
df2=pd.concat(new_list)
#df2.to_excel(r'C:\Users\Zedd\Desktop\错误值-下达项目.xlsx',index=False)

# %%
type(new_list)

# %%
type(df2)

# %%
import pandas as pd
dff1=pd.read_excel(r'C:\Users\Zedd\Desktop\Summer intern\订单分析\待清洗\回复_勘察设计待清洗汇总 4张表\汇总2张表\下达项目+错误值.xlsx')
dff2=pd.read_excel(r'C:\Users\Zedd\Desktop\Summer intern\订单分析\待清洗\回复_勘察设计待清洗汇总 4张表\汇总2张表\投标+错误值.xlsx')

# %%
dff1.isnull().sum()
# Out:
# 项目类型                              0
# 组织名称                              0
# 项目编号                              0
# 项目全称                              0
# 省份                                0
# 城市\n（值列表点选勿手输）                  338
# 项目批准日期                            2
# 项目阶段                              0
# 客户名称\n（手动输入客户全称，必须在系统客户名录中）       1
# 主体院名称\n（值列表点选勿手输）                 0
# 项目特征分类                            0
# 项目信息来源\n（值列表点选勿手输）             1467
# 预估阶段金额                            0
# 项目属性细分\n（值列表点选勿手输）             2373
# dtype: int64

# %%
dff1.shape
# Out:
# (32762, 14)

# %%
dff1['主体院名称\n（值列表点选勿手输）'].value_counts()
# Out:
# 上海市政交通设计研究院有限公司              4887
# 道路桥梁设计研究院                    3060
# 综合交通规划设计研究院                  2465
# 上海市政工程设计研究总院集团第十市政设计院有限公司    2192
# 城市交通与地下空间设计研究院               1973
# 上海斯美设计审图咨询有限公司               1742
# 第三设计研究院                      1680
# 综合设计研究院                      1575
# 第四设计研究院                      1438
# 水利水运设计研究院                    1395
# 第二设计研究院                      1373
# 第一设计研究院                      1207
# 景观规划设计研究院                    1177
# 勘察设计院                        1109
# 上海市政工程设计研究总院集团第六设计院有限公司       990
# 第五设计研究院                       965
# 研究院                           737
# 上海城市交通设计院有限公司                 492
# 城市建筑设计研究院                     475
# 上海市政工程设计研究总院集团广东有限公司          469
# 大桥设计研究院                       457
# 上海水业设计工程有限公司                  451
# 城乡规划设计研究院                     286
# 上海市政工程设计研究总院集团新疆有限公司          126
# 工程造价咨询研究院                      21
# 城市轨道与铁路设计研究院                   19
# 研究院（土壤中心）                       1
# ...

# %%
dff1.iloc[0:9,0:4]
# Out:
#    项目类型   组织名称          项目编号                            项目全称
# 0  设计咨询  市政交通院   202010-532F       大同市北都街南一路（友谊街～御河西路）道路建设工程
# 1  设计咨询  市政交通院   202010-532A     大同市南环东延北一路（御河东路～文瀛西路）道路建设工程
# 2  设计咨询  市政交通院   202010-532B      大同市东小城东侧道路（滨河北路～迎宾街）道路建设工程
# 3  设计咨询  市政交通院   202010-532C         大同市长青街（御河西路～龙园西路）道路建设工程
# 4  设计咨询  市政交通院   202010-532E     大同市友谊街东一路（北都街南一路～北都街）道路建设工程
# 5  设计咨询  市政交通院   202009-010B               崇明农村市政道路改建工程前柴路工程
# 6  设计咨询  市政交通院  202009-608-3                          A5大修工程
# 7  设计咨询  市政交通院   202009-010A              崇明农村市政道路改建工程江申南路工程
# 8  设计咨询   市政总院    2011SKD002  2012年度黄浦江上游堤防专项维修工程2标（干流段及大泖港）

# %%
len(dff1)
# Out:
# 32762

# %%
dff2.isnull().sum()
# Out:
# 项目类型                                   0
# 组织名称                                   0
# 项目编号                                   0
# 项目全称                                   0
# 省份                                     0
# 城市\n（值列表点选勿手输）                        24
# 项目批准日期                               123
# 项目阶段                                 123
# 投标项目分类                               235
# 客户名称\n（手动输入客户全称，必须在系统客户名录中）            0
# 主体院名称\n（值列表点选勿手输）                      0
# 项目特征分类\n（值列表点选勿手输）                     0
# 是否中标\n（值列表点选勿手输）                     297
# 中标金额（单位元）\n（手输，单位元，仅限数字，仅限中标项目）      822
# 投标信息来源\n（值列表点选勿手输）                   149
# 项目属性细分\n（值列表点选勿手输）                   686
# 预估报价金额（单位元）\n（手输，单位元，仅限数字，仅限失标项目）    157
# dtype: int64

# %%
dff2.shape
# Out:
# (6446, 17)

# %%
import gc
gc.collect()
# Out:
# 6978

# %%
import pandas as pd
import numpy as np
list1=[1,2,3]
list2=[1,2,3]
list1.append(list2)
list1
# Out:
# [1, 2, 3, [1, 2, 3]]

# %%
list1.append(10)
list1
# Out:
# [1, 2, 3, [1, 2, 3], 10, 10]

# %%
list3=pd.DataFrame()
list4=[[2,3,4],[4,5,6]]
list3=list3.append(list4,ignore_index=True)
list3
# Out:
#    0  1  2
# 0  2  3  4
# 1  4  5  6

# %%
data = pd.DataFrame()
a = [[1,2,3],[4,5,6]]
data = data.append(a)
a = [[7,8,9],[10,11,12]]
data = data.append(a)
print(data)
# Out:
#     0   1   2
# 0   1   2   3
# 1   4   5   6
# 0   7   8   9
# 1  10  11  12

# %% [markdown]
# **<font color=red>--OS库的使用--</font>**

# %%
import os
import pandas as pd

t=0
new_list=[]
file_path='C:\\Users\\Zedd\\Desktop\\Summer intern\\订单分析\\待清洗\\回复22-勘察设计'
zty_list=['上海市政交通设计研究院有限公司','研究院','综合设计研究院','第五设计研究院','水利水运设计研究院','上海市政工程设计研究总院集团第十市政设计院有限公司','研究院（土壤中心）','景观规划设计研究院','城市建筑设计研究院','第二设计研究院','工程造价咨询研究院','第四设计研究院','上海市政工程设计研究总院集团新疆有限公司','上海水业设计工程有限公司','上海斯美设计审图咨询有限公司','数字工程设计院','勘察设计院','第三设计研究院','上海市政工程设计研究总院集团第六设计院有限公司','城乡规划设计研究院','城市轨道与铁路设计研究院','道路桥梁设计研究院','综合交通规划设计研究院','大桥设计研究院','上海城市交通设计院有限公司','城市交通与地下空间设计研究院','上海市政工程设计研究总院集团广东有限公司']
file_list=os.listdir(file_path)
list1=['申环公司，没表2','数字院，仅表3']
list2=['轨道铁路院，无表1','数字院，仅表3']
list3=[]
list4=['数字院，仅表3']
for i in file_list:
    if  i not in list3:
        path=os.path.join(file_path,i)
        df=pd.read_excel(path+'\订单分析数据待清洗-项目属性细分错误值-勘察设计-投标.xlsx')
        df1=df[df['主体院名称']==zty_list[t]]
        new_list.append(df1)
        print(zty_list[t])
        t+=1
    else:
        print('jump over'+zty_list[t])
        t+=1
        continue
df2=pd.concat(new_list,join='inner',ignore_index=True)
df2.to_excel(r'C:\Users\Zedd\Desktop\错误值-投标.xlsx',index=False)
# Out:
# 上海市政交通设计研究院有限公司
# 研究院
# 综合设计研究院
# 第五设计研究院
# 水利水运设计研究院
# 上海市政工程设计研究总院集团第十市政设计院有限公司
# 研究院（土壤中心）
# 景观规划设计研究院
# 城市建筑设计研究院
# 第二设计研究院
# 工程造价咨询研究院
# 第四设计研究院
# 上海市政工程设计研究总院集团新疆有限公司
# 上海水业设计工程有限公司
# 上海斯美设计审图咨询有限公司
# 数字工程设计院
# 勘察设计院
# 第三设计研究院
# 上海市政工程设计研究总院集团第六设计院有限公司
# 城乡规划设计研究院
# 城市轨道与铁路设计研究院
# 道路桥梁设计研究院
# 综合交通规划设计研究院
# 大桥设计研究院
# 上海城市交通设计院有限公司
# 城市交通与地下空间设计研究院
# 上海市政工程设计研究总院集团广东有限公司

# %%
new_list=[]
for i in file_list:
    new_path=os.path.join(file_path,i)
    new_list.append(os.listdir(new_path))
new_list
# Out:
# [['订单分析待清洗-勘察设计-下达项目.xlsx',
#   '订单分析数据待清洗-勘察设计-投标.xlsx',
#   '订单分析数据待清洗-项目属性细分错误值-勘察设计-下达项目.xlsx',
#   '订单分析数据待清洗-项目属性细分错误值-勘察设计-投标.xlsx'],
#  ['订单分析待清洗-勘察设计-下达项目.xlsx',
#   '订单分析数据待清洗-勘察设计-投标.xlsx',
#   '订单分析数据待清洗-项目属性细分错误值-勘察设计-下达项目.xlsx',
#   '订单分析数据待清洗-项目属性细分错误值-勘察设计-投标.xlsx'],
#  ['订单分析待清洗-勘察设计-下达项目.xlsx',
#   '订单分析数据待清洗-勘察设计-投标.xlsx',
#   '订单分析数据待清洗-项目属性细分错误值-勘察设计-下达项目.xlsx',
#   '订单分析数据待清洗-项目属性细分错误值-勘察设计-投标.xlsx'],
#  ['订单分析待清洗-勘察设计-下达项目.xlsx',
#   '订单分析数据待清洗-勘察设计-投标.xlsx',
#   '订单分析数据待清洗-项目属性细分错误值-勘察设计-下达项目.xlsx',
#   '订单分析数据待清洗-项目属性细分错误值-勘察设计-投标.xlsx'],
#  ['订单分析待清洗-勘察设计-下达项目.xlsx',
#   '订单分析数据待清洗-勘察设计-投标.xlsx',
#   '订单分析数据待清洗-项目属性细分错误值-勘察设计-下达项目.xlsx',
#   '订单分析数据待清洗-项目属性细分错误值-勘察设计-投标.xlsx'],
#  ['订单分析待清洗-勘察设计-下达项目.xlsx',
#   '订单分析数据待清洗-勘察设计-投标.xlsx',
#   '订单分析数据待清洗-项目属性细分错误值-勘察设计-下达项目.xlsx',
#   '订单分析数据待清洗-项目属性细分错误值-勘察设计-投标.xlsx'],
#  ['订单分析待清洗-勘察设计-下达项目.xlsx',
#   '订单分析数据待清洗-勘察设计-投标.xlsx',
#   '订单分析数据待清洗-项目属性细分错误值-勘察设计-下达项目.xlsx',
# ...

# %%
path
# Out:
# 'C:\\Users\\Zedd\\Desktop\\Summer intern\\订单分析\\待清洗\\回复22-勘察设计\\道桥院'

# %%
file_list
# Out:
# ['三院',
#  '二院',
#  '五院',
#  '交规院',
#  '六院',
#  '勘察公司',
#  '十院',
#  '四院',
#  '城市交通院',
#  '城郊地下院',
#  '大桥院',
#  '审图公司',
#  '市政交通院',
#  '广东公司',
#  '建筑院',
#  '数字院，仅表3',
#  '新疆公司',
#  '景观院',
#  '水业公司',
#  '水利水运院',
#  '申环公司，没表2',
#  '研究院',
#  '综合院',
#  '规划院',
#  '轨道铁路院，无表1',
#  '造价公司',
#  '道桥院']

# %%
dd=pd.read_excel(r'C:\Users\Zedd\Desktop\错误值-投标.xlsx')
dd.isnull().sum()
# Out:
# 项目类型                                   0
# 组织名称                                   0
# 项目编号                                   0
# 项目全称                                   0
# 省份                                     0
# 城市\n（值列表点选勿手输）                        51
# 项目批准日期                                 0
# 项目阶段                                   0
# 客户名称\n（手动输入客户全称，必须在系统客户名录中）            1
# 主体院名称                                  0
# 项目特征分类                                 0
# 是否中标\n（值列表点选勿手输）                      17
# 中标金额\n（手输，单位元，仅限数字，仅限中标项目）           145
# 投标信息来源\n（值列表点选勿手输）                     7
# 预估报价金额（单位元）\n（手输，单位元，仅限数字，仅限失标项目）      0
# 原项目属性细分                                0
# 新项目属性细分\n（值列表点选勿手输）                  896
# dtype: int64

# %%
len(dd)
# Out:
# 898

# %%
import pandas as pd
df1=pd.read_excel(r'C:\Users\Zedd\Desktop\下达项目.xlsx')
df2=pd.read_excel(r'C:\Users\Zedd\Desktop\投标.xlsx')
df3=pd.read_excel(r'C:\Users\Zedd\Desktop\BI数据清洗总包项目_V2.xlsx')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a17ba95d3ec5> in <module>
#       3 df2=pd.read_excel(r'C:\Users\Zedd\Desktop\投标.xlsx')
#       4 df3=pd.read_excel(r'C:\Users\Zedd\Desktop\BI数据清洗总包项目_V2.xlsx')
# ----> 5 d4=pd.concat([d1,d2,d3],ignore_index=True,join='outer')
#       6 d4.sample(5)
#
# NameError: name 'd1' is not defined

# %%
d4=pd.concat([df1,df2,df3],ignore_index=True,join='outer')
d4.sample(5)
# Out:
#        项目类型  组织名称         项目编号                                    项目全称   省份  \
# 31249  设计咨询   道桥院  2020SH090QZ                 Y4路（临港大道-东大公路）道路新建工程-咨询  上海市
# 19936  设计咨询   交规院     2011Q084                           天津蓟汕联络线高速公路工程  天津市
# 33485    投标  市政总院    T2012Q032                       威海市垃圾处理厂填埋场雨污分流工程  山东省
# 18936  设计咨询   道桥院  2015SH248CS    上海市宝山区顾村拓展区市政配套工程沪联路（仁孝路-联杨路）新建工程-初设  上海市
# 21545  设计咨询   交规院  2016SH646SS  上海市顺平路（德惠路~隆昌路）、德惠路（顺平路~周家嘴路）道路新建工程-施设  上海市
#
#          城市              项目批准日期    项目阶段 客户名称\n（手动输入客户全称，必须在系统客户名录中）  \
# 31249  浦东新区 2020-03-18 14:16:45  前期咨询阶段              上海临港新城投资建设有限公司
# 19936   天津市 2011-08-30 00:00:00    初步设计                天津高速公路集团有限公司
# 33485   威海市 2012-01-01 00:00:00    设计投标                    威海市垃圾处理厂
# 18936   宝山区 2016-06-08 15:00:58    初步设计              上海地产北部投资发展有限公司
# 21545   杨浦区 2017-11-21 17:17:34   施工图设计           上海市杨浦区市政和水务管理事务中心
#
#       主体院名称\n（值列表点选勿手输）  ... 投标信息来源\n（值列表点选勿手输）  \
# ...

# %%
d5=d4[['项目编号','省份','城市']]
d5.to_excel(r'C:\Users\Zedd\Desktop\test.xlsx',index=False)

# %%
import pandas as pd
import numpy as np
d1=pd.DataFrame(np.random.randn(5,5),columns=list('abcde'))

# %%
d1
# Out:
#           a         b         c         d         e
# 0  0.155853 -0.162452  1.698561  0.748071  0.461152
# 1 -0.130426  0.833213 -0.014836 -1.425901 -0.413849
# 2 -0.387930  1.137546  0.662750 -0.480722  1.238181
# 3 -1.865069 -0.611663 -1.345363 -1.333434  0.195554
# 4 -0.154972  0.629300  0.178178 -0.645984  0.393588

# %%
d1[d1.c>0]
# Out:
#           a         b         c         d         e
# 0  0.155853 -0.162452  1.698561  0.748071  0.461152
# 2 -0.387930  1.137546  0.662750 -0.480722  1.238181
# 4 -0.154972  0.629300  0.178178 -0.645984  0.393588

# %%
d2=pd.DataFrame(np.random.randint(1,100,(5,5)),columns=list('abcde'))
d2
# Out:
#     a   b   c   d   e
# 0  17  31  22  57  40
# 1  18  96  87  28  23
# 2  82  30  11  37  85
# 3  63  58  72  92  52
# 4  69   7  70  81  38

# %%
a=list(d2.a.unique())
a
# Out:
# [17, 18, 82, 63, 69]

# %%
d2.a.mean()
# Out:
# 49.8

# %%
d2=d2.a.apply(lambda x:x*2)

# %%
d2
# Out:
# 0     34
# 1     36
# 2    164
# 3    126
# 4    138
# Name: a, dtype: int64
